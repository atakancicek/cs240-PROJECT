# %%
import pandas as pd
import csv

# %%
output = open("AllstarFull.csv", "rb")
data = pd.read_csv("AllstarFull.csv")

# %%
data
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID   GP  startingPos
# 0     gomezle01    1933        0  ALS193307060    NYA   AL  1.0          1.0
# 1     ferreri01    1933        0  ALS193307060    BOS   AL  1.0          2.0
# 2     gehrilo01    1933        0  ALS193307060    NYA   AL  1.0          3.0
# 3     gehrich01    1933        0  ALS193307060    DET   AL  1.0          4.0
# 4     dykesji01    1933        0  ALS193307060    CHA   AL  1.0          5.0
# 5     cronijo01    1933        0  ALS193307060    WS1   AL  1.0          6.0
# 6     chapmbe01    1933        0  ALS193307060    NYA   AL  1.0          7.0
# 7     simmoal01    1933        0  ALS193307060    CHA   AL  1.0          8.0
# 8      ruthba01    1933        0  ALS193307060    NYA   AL  1.0          9.0
# 9     averiea01    1933        0  ALS193307060    CLE   AL  1.0          NaN
# 10    crowdal01    1933        0  ALS193307060    WS1   AL  1.0          NaN
# 11    dickebi01    1933        0  ALS193307060    NYA   AL  0.0          NaN
# 12    ferrewe01    1933        0  ALS193307060    CLE   AL  0.0          NaN
# 13     foxxji01    1933        0  ALS193307060    PHA   AL  0.0          NaN
# 14    grovele01    1933        0  ALS193307060    PHA   AL  1.0          NaN
# 15    hildeor01    1933        0  ALS193307060    CLE   AL  0.0          NaN
# 16    lazzeto01    1933        0  ALS193307060    NYA   AL  0.0          NaN
# 17     westsa01    1933        0  ALS193307060    SLA   AL  1.0          NaN
# 18    hallabi01    1933        0  ALS193307060    SLN   NL  1.0          1.0
# 19    wilsoji01    1933        0  ALS193307060    SLN   NL  1.0          2.0
# 20    terrybi01    1933        0  ALS193307060    NY1   NL  1.0          3.0
# 21    friscfr01    1933        0  ALS193307060    SLN   NL  1.0          4.0
# 22    martipe01    1933        0  ALS193307060    SLN   NL  1.0          5.0
# 23    bartedi01    1933        0  ALS193307060    PHI   NL  1.0          6.0
# 24    hafeych01    1933        0  ALS193307060    CIN   NL  1.0          7.0
# 25    bergewa01    1933        0  ALS193307060    BSN   NL  1.0          8.0
# 26    kleinch01    1933        0  ALS193307060    PHI   NL  1.0          9.0
# 27    cuccito01    1933        0  ALS193307060    BRO   NL  1.0          NaN
# 28    engliwo01    1933        0  ALS193307060    CHN   NL  1.0          NaN
# 29    hartnga01    1933        0  ALS193307060    CHN   NL  1.0          NaN
# ...         ...     ...      ...           ...    ...  ...  ...          ...
# 5118  cespeyo01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5119  colonba01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5120  familje01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5121  fernajo02    2016        0  ALS201607120    MIA   NL  1.0          NaN
# 5122  goldspa01    2016        0  ALS201607120    ARI   NL  1.0          NaN
# 5123  gonzaca01    2016        0  ALS201607120    COL   NL  1.0          7.0
# 5124  harpebr03    2016        0  ALS201607120    WAS   NL  1.0          9.0
# 5125  herreod01    2016        0  ALS201607120    PHI   NL  1.0          NaN
# 5126  janseke01    2016        0  ALS201607120    LAN   NL  1.0          NaN
# 5127  kershcl01    2016        0  ALS201607120    LAN   NL  0.0          NaN
# 5128  lestejo01    2016        0  ALS201607120    CHN   NL  1.0          NaN
# 5129  lucrojo01    2016        0  ALS201607120    MIL   NL  1.0          NaN
# 5130  martest01    2016        0  ALS201607120    PIT   NL  1.0          NaN
# 5131  melanma01    2016        0  ALS201607120    PIT   NL  1.0          NaN
# 5132  murphda08    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5133  myerswi01    2016        0  ALS201607120    SDN   NL  1.0          0.0
# 5134  ozunama01    2016        0  ALS201607120    MIA   NL  1.0          8.0
# 5135  pomerdr01    2016        0  ALS201607120    SDN   NL  1.0          NaN
# 5136  poseybu01    2016        0  ALS201607120    SFN   NL  1.0          2.0
# 5137  ramosaj01    2016        0  ALS201607120    MIA   NL  0.0          NaN
# 5138  ramoswi01    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5139  rizzoan01    2016        0  ALS201607120    CHN   NL  1.0          3.0
# 5140  rodnefe01    2016        0  ALS201607120    MIA   NL  1.0          NaN
# 5141  russead02    2016        0  ALS201607120    CHN   NL  1.0          6.0
# 5142  scherma01    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5143  seageco01    2016        0  ALS201607120    LAN   NL  1.0          NaN
# 5144  strasst01    2016        0  ALS201607120    WAS   NL  0.0          NaN
# 5145  syndeno01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5146  teherju01    2016        0  ALS201607120    ATL   NL  1.0          NaN
# 5147  zobribe01    2016        0  ALS201607120    CHN   NL  1.0          4.0
#
# [5148 rows x 8 columns]

# %%
#playerID : Player ID code 
#yearID : Year
#gameNum : Game number (zero if only one All-Star game played that season)
#gameID : Retrosheet ID for the game idea
#TeamID : Team name
#lgID : League Name
#GP : Games played (1.0 if played in the game)
#startingPos : If the player was started, its position

# %%
years = data['yearID']

# %%
years
# Out:
# 0       1933
# 1       1933
# 2       1933
# 3       1933
# 4       1933
# 5       1933
# 6       1933
# 7       1933
# 8       1933
# 9       1933
# 10      1933
# 11      1933
# 12      1933
# 13      1933
# 14      1933
# 15      1933
# 16      1933
# 17      1933
# 18      1933
# 19      1933
# 20      1933
# 21      1933
# 22      1933
# 23      1933
# 24      1933
# 25      1933
# 26      1933
# 27      1933
# 28      1933
# 29      1933
#         ...
# 5118    2016
# 5119    2016
# 5120    2016
# 5121    2016
# 5122    2016
# 5123    2016
# 5124    2016
# 5125    2016
# 5126    2016
# 5127    2016
# 5128    2016
# 5129    2016
# 5130    2016
# 5131    2016
# 5132    2016
# 5133    2016
# 5134    2016
# 5135    2016
# 5136    2016
# 5137    2016
# 5138    2016
# 5139    2016
# 5140    2016
# 5141    2016
# 5142    2016
# 5143    2016
# 5144    2016
# 5145    2016
# 5146    2016
# 5147    2016
# Name: yearID, dtype: int64

# %%
leagues = data['lgID']

# %%
leagues
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AL
# 16      AL
# 17      AL
# 18      NL
# 19      NL
# 20      NL
# 21      NL
# 22      NL
# 23      NL
# 24      NL
# 25      NL
# 26      NL
# 27      NL
# 28      NL
# 29      NL
#         ..
# 5118    NL
# 5119    NL
# 5120    NL
# 5121    NL
# 5122    NL
# 5123    NL
# 5124    NL
# 5125    NL
# 5126    NL
# 5127    NL
# 5128    NL
# 5129    NL
# 5130    NL
# 5131    NL
# 5132    NL
# 5133    NL
# 5134    NL
# 5135    NL
# 5136    NL
# 5137    NL
# 5138    NL
# 5139    NL
# 5140    NL
# 5141    NL
# 5142    NL
# 5143    NL
# 5144    NL
# 5145    NL
# 5146    NL
# 5147    NL
# Name: lgID, dtype: object

# %%
data.sort_values(by='GP')
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID   GP  startingPos
# 2443  harrato01    1975        0  ALS197507150    TEX   AL  0.0          NaN
# 1063  turlebo01    1954        0  ALS195407130    BAL   AL  0.0          NaN
# 4402  jenksbo01    2007        0  NLS200707100    CHA   AL  0.0          NaN
# 4403  lackejo01    2007        0  NLS200707100    LAA   AL  0.0          NaN
# 1060  reynoal01    1954        0  ALS195407130    NYA   AL  0.0          NaN
# 3398  mcgwima01    1991        0  ALS199107090    OAK   AL  0.0          NaN
# 4406  mechegi01    2007        0  NLS200707100    KCA   AL  0.0          NaN
# 1056  lollash01    1954        0  ALS195407130    CHA   AL  0.0          NaN
# 2376  bandosa01    1974        0  NLS197407230    OAK   AL  0.0          NaN
# 1054  kuennha01    1954        0  ALS195407130    DET   AL  0.0          NaN
# 1053   kellge01    1954        0  ALS195407130    CHA   AL  0.0          NaN
# 4408  okajihi01    2007        0  NLS200707100    BOS   AL  0.0          NaN
# 1051  garcimi01    1954        0  ALS195407130    CLE   AL  0.0          NaN
# 2377  busbyst01    1974        0  NLS197407230    KCA   AL  0.0          NaN
# 1049  finigji01    1954        0  ALS195407130    PHA   AL  0.0          NaN
# 1048   fainfe01    1954        0  ALS195407130    CHA   AL  0.0          NaN
# 2379  cuellmi01    1974        0  NLS197407230    BAL   AL  0.0          NaN
# 3396  langsma01    1991        0  ALS199107090    CAL   AL  0.0          NaN
# 3403  sandesc01    1991        0  ALS199107090    NYA   AL  0.0          NaN
# 4388  zambrca01    2006        0  NLS200607110    CHN   NL  0.0          NaN
# 1079  crandde01    1954        0  ALS195407130    ML1   NL  0.0          NaN
# 4386  ugglada01    2006        0  NLS200607110    FLO   NL  0.0          NaN
# 1106  hoeftbi01    1955        0  NLS195507120    DET   AL  0.0          NaN
# 4366  capuach01    2006        0  NLS200607110    MIL   NL  0.0          NaN
# 1104  donovdi01    1955        0  NLS195507120    CHA   AL  0.0          NaN
# 1103   dobyla01    1955        0  NLS195507120    CLE   AL  0.0          NaN
# 4367  carpech01    2006        0  NLS200607110    SLN   NL  0.0          NaN
# 3423   krukjo01    1991        0  ALS199107090    PHI   NL  0.0          NaN
# 2350  conceda01    1973        0  ALS197307240    CIN   NL  0.0          NaN
# 4370  garcino01    2006        0  NLS200607110    LAN   NL  0.0          NaN
# ...         ...     ...      ...           ...    ...  ...  ...          ...
# 2038   wertdo01    1968        0  NLS196807090    DET   AL  1.0          NaN
# 2086  mclaide01    1969        0  ALS196907230    DET   AL  1.0          NaN
# 2037  stottme01    1968        0  NLS196807090    NYA   AL  1.0          NaN
# 2034  olivato01    1968        0  NLS196807090    MIN   AL  1.0          NaN
# 2033   odombl01    1968        0  NLS196807090    OAK   AL  1.0          NaN
# 2032  mondari01    1968        0  NLS196807090    OAK   AL  1.0          NaN
# 2031  mclaide01    1968        0  NLS196807090    DET   AL  1.0          NaN
# 2030  mcdowsa01    1968        0  NLS196807090    CLE   AL  1.0          NaN
# 2029  mantlmi01    1968        0  NLS196807090    NYA   AL  1.0          NaN
# 2035  powelbo01    1968        0  NLS196807090    BAL   AL  1.0          NaN
# 5147  zobribe01    2016        0  ALS201607120    CHN   NL  1.0          4.0
# 5050  santihe01    2015        0  NLS201507141    LAA   AL  NaN          NaN
# 5051   grayso01    2015        0  NLS201507142    OAK   AL  NaN          NaN
# 5052  bautijo02    2015        0  NLS201507143    TOR   AL  NaN          NaN
# 5053  millesh01    2015        0  NLS201507144    ATL   NL  NaN          NaN
# 5054  martica04    2015        0  NLS201507145    SLN   NL  NaN          NaN
# 5055  wachami01    2015        0  NLS201507146    SLN   NL  NaN          NaN
# 5056  rosentr01    2015        0  NLS201507147    SLN   NL  NaN          NaN
# 5057  hollima01    2015        0  NLS201507148    SLN   NL  NaN          NaN
# 5058  gordode01    2015        0  NLS201507149    MIA   NL  NaN          NaN
# 5059  stantmi03    2015        0  NLS201507150    MIA   NL  NaN          NaN
# 5060  scherma01    2015        0  NLS201507151    WAS   NL  NaN          NaN
# 5061   odayda01    2015        0  NLS201507152    BAL   AL  NaN          NaN
# 5062  papeljo01    2015        0  NLS201507153    PHI   NL  NaN          NaN
# 5063  burneaj01    2015        0  NLS201507154    PIT   NL  NaN          NaN
# 5064  boxbebr01    2015        0  NLS201507155    TBA   AL  NaN          NaN
# 5065  gordoal01    2015        0  NLS201507156    KCA   AL  NaN          NaN
# 5066  herreke01    2015        0  NLS201507157    KCA   AL  NaN          NaN
# 5067  cabremi01    2015        0  NLS201507158    DET   AL  NaN          NaN
# 5068   salech01    2015        0  NLS201507159    CHA   AL  NaN          NaN
#
# [5148 rows x 8 columns]

# %%
pd.value_counts(data['GP'].values, sort=False)
# Out:
# 1.0    3990
# 0.0    1139
# dtype: int64

# %%
#There are 3990 players that played in the all-star game, and there are 1139 players that didn't played in the all-star game

# %%
#Since we have different type of leagues(AL, NL), now i have to specify how many players played in AL league, and how many
#played in NL league.

# %%
#getting every data about AL league

# %%
al = data[data.lgID == 'AL']

# %%
al
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID   GP  startingPos
# 0     gomezle01    1933        0  ALS193307060    NYA   AL  1.0          1.0
# 1     ferreri01    1933        0  ALS193307060    BOS   AL  1.0          2.0
# 2     gehrilo01    1933        0  ALS193307060    NYA   AL  1.0          3.0
# 3     gehrich01    1933        0  ALS193307060    DET   AL  1.0          4.0
# 4     dykesji01    1933        0  ALS193307060    CHA   AL  1.0          5.0
# 5     cronijo01    1933        0  ALS193307060    WS1   AL  1.0          6.0
# 6     chapmbe01    1933        0  ALS193307060    NYA   AL  1.0          7.0
# 7     simmoal01    1933        0  ALS193307060    CHA   AL  1.0          8.0
# 8      ruthba01    1933        0  ALS193307060    NYA   AL  1.0          9.0
# 9     averiea01    1933        0  ALS193307060    CLE   AL  1.0          NaN
# 10    crowdal01    1933        0  ALS193307060    WS1   AL  1.0          NaN
# 11    dickebi01    1933        0  ALS193307060    NYA   AL  0.0          NaN
# 12    ferrewe01    1933        0  ALS193307060    CLE   AL  0.0          NaN
# 13     foxxji01    1933        0  ALS193307060    PHA   AL  0.0          NaN
# 14    grovele01    1933        0  ALS193307060    PHA   AL  1.0          NaN
# 15    hildeor01    1933        0  ALS193307060    CLE   AL  0.0          NaN
# 16    lazzeto01    1933        0  ALS193307060    NYA   AL  0.0          NaN
# 17     westsa01    1933        0  ALS193307060    SLA   AL  1.0          NaN
# 36    gomezle01    1934        0  NLS193407100    NYA   AL  1.0          1.0
# 37    dickebi01    1934        0  NLS193407100    NYA   AL  1.0          2.0
# 38    gehrilo01    1934        0  NLS193407100    NYA   AL  1.0          3.0
# 39    gehrich01    1934        0  NLS193407100    DET   AL  1.0          4.0
# 40     foxxji01    1934        0  NLS193407100    PHA   AL  1.0          5.0
# 41    cronijo01    1934        0  NLS193407100    WS1   AL  1.0          6.0
# 42    manushe01    1934        0  NLS193407100    WS1   AL  1.0          7.0
# 43    simmoal01    1934        0  NLS193407100    CHA   AL  1.0          8.0
# 44     ruthba01    1934        0  NLS193407100    NYA   AL  1.0          9.0
# 45    averiea01    1934        0  NLS193407100    CLE   AL  1.0          NaN
# 46    bridgto01    1934        0  NLS193407100    DET   AL  0.0          NaN
# 47    chapmbe01    1934        0  NLS193407100    NYA   AL  1.0          NaN
# ...         ...     ...      ...           ...    ...  ...  ...          ...
# 5077  cabremi01    2016        0  ALS201607120    DET   AL  1.0          NaN
# 5078  daviswa01    2016        0  ALS201607120    KCA   AL  0.0          NaN
# 5079   canoro01    2016        0  ALS201607120    SEA   AL  1.0          NaN
# 5080  colomal01    2016        0  ALS201607120    TBA   AL  0.0          NaN
# 5081  desmoia01    2016        0  ALS201607120    TEX   AL  1.0          NaN
# 5082  donaljo02    2016        0  ALS201607120    TOR   AL  1.0          NaN
# 5083  encared01    2016        0  ALS201607120    TOR   AL  1.0          NaN
# 5084  estrama01    2016        0  ALS201607120    TOR   AL  0.0          NaN
# 5085  hamelco01    2016        0  ALS201607120    TEX   AL  1.0          NaN
# 5086  harriwi02    2016        0  ALS201607120    HOU   AL  1.0          NaN
# 5087  herreke01    2016        0  ALS201607120    KCA   AL  1.0          NaN
# 5088  hosmeer01    2016        0  ALS201607120    KCA   AL  1.0          3.0
# 5089  kimbrcr01    2016        0  ALS201607120    BOS   AL  0.0          NaN
# 5090  klubeco01    2016        0  ALS201607120    CLE   AL  1.0          NaN
# 5091  lindofr01    2016        0  ALS201607120    CLE   AL  1.0          NaN
# 5092  machama01    2016        0  ALS201607120    BAL   AL  1.0          5.0
# 5093  millean01    2016        0  ALS201607120    NYA   AL  1.0          NaN
# 5094  nunezed02    2016        0  ALS201607120    MIN   AL  1.0          NaN
# 5095  ortizda01    2016        0  ALS201607120    BOS   AL  1.0          0.0
# 5096  perezsa02    2016        0  ALS201607120    KCA   AL  1.0          2.0
# 5097  quintjo01    2016        0  ALS201607120    CHA   AL  1.0          NaN
# 5098  salazda01    2016        0  ALS201607120    CLE   AL  0.0          NaN
# 5099   salech01    2016        0  ALS201607120    CHA   AL  1.0          1.0
# 5100  sanchaa01    2016        0  ALS201607120    TOR   AL  1.0          NaN
# 5101  saundmi01    2016        0  ALS201607120    TOR   AL  1.0          NaN
# 5102  troutmi01    2016        0  ALS201607120    LAA   AL  1.0          8.0
# 5103  trumbma01    2016        0  ALS201607120    BAL   AL  1.0          NaN
# 5104   vogtst01    2016        0  ALS201607120    OAK   AL  0.0          NaN
# 5105  wietema01    2016        0  ALS201607120    BAL   AL  1.0          NaN
# 5106  wrighst01    2016        0  ALS201607120    BOS   AL  0.0          NaN
#
# [2582 rows x 8 columns]

# %%
#now, getting the data about NL league

# %%
nl = data[data.lgID == 'NL']

# %%
nl
# Out:
#        playerID  yearID  gameNum        gameID teamID lgID   GP  startingPos
# 18    hallabi01    1933        0  ALS193307060    SLN   NL  1.0          1.0
# 19    wilsoji01    1933        0  ALS193307060    SLN   NL  1.0          2.0
# 20    terrybi01    1933        0  ALS193307060    NY1   NL  1.0          3.0
# 21    friscfr01    1933        0  ALS193307060    SLN   NL  1.0          4.0
# 22    martipe01    1933        0  ALS193307060    SLN   NL  1.0          5.0
# 23    bartedi01    1933        0  ALS193307060    PHI   NL  1.0          6.0
# 24    hafeych01    1933        0  ALS193307060    CIN   NL  1.0          7.0
# 25    bergewa01    1933        0  ALS193307060    BSN   NL  1.0          8.0
# 26    kleinch01    1933        0  ALS193307060    PHI   NL  1.0          9.0
# 27    cuccito01    1933        0  ALS193307060    BRO   NL  1.0          NaN
# 28    engliwo01    1933        0  ALS193307060    CHN   NL  1.0          NaN
# 29    hartnga01    1933        0  ALS193307060    CHN   NL  1.0          NaN
# 30    hubbeca01    1933        0  ALS193307060    NY1   NL  1.0          NaN
# 31    odoulle01    1933        0  ALS193307060    NY1   NL  1.0          NaN
# 32    schumha02    1933        0  ALS193307060    NY1   NL  0.0          NaN
# 33    traynpi01    1933        0  ALS193307060    PIT   NL  1.0          NaN
# 34    wanerpa01    1933        0  ALS193307060    PIT   NL  1.0          NaN
# 35    warnelo01    1933        0  ALS193307060    CHN   NL  1.0          NaN
# 56    hubbeca01    1934        0  NLS193407100    NY1   NL  1.0          1.0
# 57    hartnga01    1934        0  NLS193407100    CHN   NL  1.0          2.0
# 58    terrybi01    1934        0  NLS193407100    NY1   NL  1.0          3.0
# 59    friscfr01    1934        0  NLS193407100    SLN   NL  1.0          4.0
# 60    traynpi01    1934        0  NLS193407100    PIT   NL  1.0          5.0
# 61    jackstr01    1934        0  NLS193407100    NY1   NL  1.0          6.0
# 62    medwijo01    1934        0  NLS193407100    SLN   NL  1.0          7.0
# 63    bergewa01    1934        0  NLS193407100    BSN   NL  1.0          8.0
# 64    cuyleki01    1934        0  NLS193407100    CHN   NL  1.0          9.0
# 65     deandi01    1934        0  NLS193407100    SLN   NL  1.0          NaN
# 66    frankfr02    1934        0  NLS193407100    BSN   NL  1.0          NaN
# 67    hermabi01    1934        0  NLS193407100    CHN   NL  1.0          NaN
# ...         ...     ...      ...           ...    ...  ...  ...          ...
# 5118  cespeyo01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5119  colonba01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5120  familje01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5121  fernajo02    2016        0  ALS201607120    MIA   NL  1.0          NaN
# 5122  goldspa01    2016        0  ALS201607120    ARI   NL  1.0          NaN
# 5123  gonzaca01    2016        0  ALS201607120    COL   NL  1.0          7.0
# 5124  harpebr03    2016        0  ALS201607120    WAS   NL  1.0          9.0
# 5125  herreod01    2016        0  ALS201607120    PHI   NL  1.0          NaN
# 5126  janseke01    2016        0  ALS201607120    LAN   NL  1.0          NaN
# 5127  kershcl01    2016        0  ALS201607120    LAN   NL  0.0          NaN
# 5128  lestejo01    2016        0  ALS201607120    CHN   NL  1.0          NaN
# 5129  lucrojo01    2016        0  ALS201607120    MIL   NL  1.0          NaN
# 5130  martest01    2016        0  ALS201607120    PIT   NL  1.0          NaN
# 5131  melanma01    2016        0  ALS201607120    PIT   NL  1.0          NaN
# 5132  murphda08    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5133  myerswi01    2016        0  ALS201607120    SDN   NL  1.0          0.0
# 5134  ozunama01    2016        0  ALS201607120    MIA   NL  1.0          8.0
# 5135  pomerdr01    2016        0  ALS201607120    SDN   NL  1.0          NaN
# 5136  poseybu01    2016        0  ALS201607120    SFN   NL  1.0          2.0
# 5137  ramosaj01    2016        0  ALS201607120    MIA   NL  0.0          NaN
# 5138  ramoswi01    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5139  rizzoan01    2016        0  ALS201607120    CHN   NL  1.0          3.0
# 5140  rodnefe01    2016        0  ALS201607120    MIA   NL  1.0          NaN
# 5141  russead02    2016        0  ALS201607120    CHN   NL  1.0          6.0
# 5142  scherma01    2016        0  ALS201607120    WAS   NL  1.0          NaN
# 5143  seageco01    2016        0  ALS201607120    LAN   NL  1.0          NaN
# 5144  strasst01    2016        0  ALS201607120    WAS   NL  0.0          NaN
# 5145  syndeno01    2016        0  ALS201607120    NYN   NL  0.0          NaN
# 5146  teherju01    2016        0  ALS201607120    ATL   NL  1.0          NaN
# 5147  zobribe01    2016        0  ALS201607120    CHN   NL  1.0          4.0
#
# [2566 rows x 8 columns]

# %%
#now i will create 2 lists, in order to calculate the players whether they played in AL league.

# %%
al_played = []
al_notplayed = []

# %%
for i in al.GP:
    if i == 1.0:
        al_played.append(i)
    if i == 0.0:
        al_notplayed.append(i)

# %%
#now, this procedure helped me to calculate the amount of players whether they played or not in the all star game

# %%
#so basically if i just say print len(list), it will give me the amount of players

# %%
#but before this, i also will make the same procedure for NL league players.

# %%
nl_played = []
nl_notplayed = []

# %%
for i in nl.GP:
    if i == 1.0:
        nl_played.append(i)
    if i == 0.0:
        nl_notplayed.append(i)

# %%
#Number of players that played in AL league all-star game:

# %%
print len(al_played)
# Out:
# 1961

# %%
#Number of player that not played in AL league all-star game:

# %%
print len(al_notplayed)
# Out:
# 612

# %%
#Number of players that played in NL league all-star game:

# %%
print len(nl_played)
# Out:
# 2029

# %%
#Number of players that not played in NL league all-star game:

# %%
print len(nl_notplayed)
# Out:
# 527

# %%
import thinkstats2
import thinkplot

# %%
#in order to make the histogram, i must assign total number of players into a variable

# %%
alPlayed = len(al_played)
alNotPlayed = len(al_notplayed)
nlPlayed = len(nl_played)
nlNotPlayed = len(nl_notplayed)

# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkstats2
import thinkplot

# %%
#now its time to draw the histogram

# %%
#total players played in all star game:
totalPlayed = alPlayed + nlPlayed

#total dnp players in all star game:
totalDNP = nlNotPlayed + alNotPlayed

# %%
#total played:
print (totalPlayed)

#total notplayed:
print (totalDNP)
# Out:
# 3990
# 1139

# %%
hist = thinkstats2.Hist({1.0:totalPlayed, 0.0:totalDNP}, label='All-star game')

# %%
thinkplot.Hist(hist)
thinkplot.Config(xlabel='All-star game played', ylabel='Total amount of players')

# %%
#This i my histogram, as you can see total played players are way much more than those who didn't played in both leagues
#all star game.

# %%
#now back into my question, which league has more players played in its own allstar game.

# %%
hist = thinkstats2.Hist({'AL League':alPlayed, 'NL League': nlPlayed}, label='All-star game')

# %%
thinkplot.Hist(hist)
thinkplot.Config(ylabel='Total amount of players')

# %%
#As we can see from the graph, NL league has slightly more players that played in the all-star game.

# %%
pmf1 = thinkstats2.Pmf({'AL League': alPlayed, 'NL League':nlPlayed} , label='All-star game')

# %%
thinkplot.Hist(pmf1)
thinkplot.Config(ylabel='Pmf')

# %%
#This is PMF, and now, here is CDF

# %%
first_cdf = thinkstats2.Cdf('AL'= alPlayed, label='AL League')
other_cdf = thinkstats2.Cdf('NL'= nlPlayed, label='NL League')
# Out:
#   File "<ipython-input-73-ed521739af2f>", line 1
#     first_cdf = thinkstats2.Cdf('AL'= alPlayed, label='AL League')
# SyntaxError: keyword can't be an expression

# %%
thinkplot.PrePlot(2)
thinkplot.Cdfs([first_cdf, other_cdf])
thinkplot.Config(ylabel='CDF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-24288c9598ea> in <module>()
#       1 thinkplot.PrePlot(2)
# ----> 2 thinkplot.Cdfs([first_cdf, other_cdf])
#       3 thinkplot.Config(ylabel='CDF')
#
# NameError: name 'first_cdf' is not defined

# %%
cdf = thinkstats2.Cdf({'AL League': alPlayed, 'NL League': nlPlayed}, label='All-star games')
thinkplot.Cdf(cdf)
thinkplot.Config(ylabel='CDF', loc='upper left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-3cc167fa6a93> in <module>()
#       1 cdf = thinkstats2.Cdf({'AL League': alPlayed, 'NL League': nlPlayed}, label='All-star games')
# ----> 2 thinkplot.Cdf(cdf)
#       3 thinkplot.Config(ylabel='CDF', loc='upper left')
#
# C:\Users\atakancicek\thinkplot.pyc in Cdf(cdf, complement, transform, **options)
#     498       Config, Show or Save.
#     499     """
# --> 500     xs, ps = cdf.Render()
#     501     xs = np.asarray(xs)
#     502     ps = np.asarray(ps)
#
# C:\Users\atakancicek\thinkstats2.pyc in Render(self, **options)
#    1221
#    1222         a = np.array(self.xs)
# -> 1223         xs = interleave(a, a)
#    1224         shift_ps = np.roll(self.ps, 1)
#    1225         shift_ps[0] = 0
#
# C:\Users\atakancicek\thinkstats2.pyc in interleave(a, b)
#    1216         def interleave(a, b):
#    1217             c = np.empty(a.shape[0] + b.shape[0])
# -> 1218             c[::2] = a
#    1219             c[1::2] = b
#    1220             return c
#
# ValueError: could not convert string to float: NL League
